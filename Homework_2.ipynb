# %% [markdown]
# ## Свёрточные нейронные сети

# %%
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf

# %% [markdown]
# #### Загрузка и подготовка датасета CIFAR-10

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

train_x = train_x.reshape(-1, 32, 32, 3).astype(np.float32) / 255.
test_x = test_x.reshape(-1, 32, 32, 3).astype(np.float32) / 255.

train_y = np.reshape(train_y, (-1)).astype(np.int32)
test_y = np.reshape(test_y, (-1)).astype(np.int32)

print(train_x.shape, train_x.dtype)
print(test_x.shape, test_x.dtype)
print(train_y.shape, train_y.dtype)
print(test_y.shape, test_y.dtype)
# Out:
# (50000, 32, 32, 3) float32
# (10000, 32, 32, 3) float32
# (50000,) int32
# (10000,) int32

# %% [markdown]
# #### Визуализация датасета

# %%
some_samples = train_x[:16, ...]

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

fig = plt.figure(figsize=(10, 6))
for j in range(some_samples.shape[0]):
    ax = fig.add_subplot(4, 8, j+1)
    ax.imshow(some_samples[j,:,:,:])
    plt.xticks([]), plt.yticks([])
    plt.imshow(train_x[j], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_y[j]])
    
plt.show()

# %% [markdown]
# #### Создание модели CNN¶

# %%
class Model(tf.keras.Model):
    
    def __init__(self):
        super(Model, self).__init__()
        
        self.conv1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')
        self.conv2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')
        self.conv3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')
        self.conv4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')
        self.max_pool = tf.keras.layers.MaxPooling2D((2, 2), (2, 2))
        self.dropout1 = tf.keras.layers.Dropout(0.25)
        self.dropout2 = tf.keras.layers.Dropout(0.25)
        self.dropout3 = tf.keras.layers.Dropout(0.5)
        self.fc1 = tf.keras.layers.Dense(512, activation='relu')
        self.fc2 = tf.keras.layers.Dense(10, activation=None)
        self.flatten = tf.keras.layers.Flatten()
        
    def call(self, inp):

        out = self.conv1(inp)
        out = self.conv2(out)
        out = self.max_pool(out)
        out = self.dropout1(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.max_pool(out)
        out = self.dropout2(out)
        out = self.flatten(out)
        out = self.fc1(out)
        out = self.dropout3(out)
        out = self.fc2(out)
        
        return out
    
model = Model()

# %% [markdown]
# #### Подготовка к обучению

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction="auto", name="sparse_categorical_crossentropy"
)

model.compile(
    optimizer="Adam", loss=loss, metrics=["accuracy"]
)

call_back = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=3,
    verbose=1,
    mode="auto",
    restore_best_weights=True,
)

# %% [markdown]
# #### Обучение модели

# %%
model.fit(train_x, train_y, 
            batch_size=32,
            epochs=50,
            validation_data=(test_x, test_y),
            callbacks=call_back
         )
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 14s 6ms/step - loss: 1.4912 - accuracy: 0.4552 - val_loss: 1.1052 - val_accuracy: 0.6066
# Epoch 2/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0843 - accuracy: 0.6153 - val_loss: 0.9100 - val_accuracy: 0.6800
# Epoch 3/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9398 - accuracy: 0.6696 - val_loss: 0.8561 - val_accuracy: 0.7017
# Epoch 4/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8551 - accuracy: 0.6989 - val_loss: 0.7810 - val_accuracy: 0.7310
# Epoch 5/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7905 - accuracy: 0.7222 - val_loss: 0.7268 - val_accuracy: 0.7499
# Epoch 6/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7403 - accuracy: 0.7398 - val_loss: 0.7147 - val_accuracy: 0.7556
# Epoch 7/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7004 - accuracy: 0.7569 - val_loss: 0.6948 - val_accuracy: 0.7636
# Epoch 8/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6622 - accuracy: 0.7686 - val_loss: 0.7270 - val_accuracy: 0.7513
# Epoch 9/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6369 - accuracy: 0.7778 - val_loss: 0.6744 - val_accuracy: 0.7704
# Epoch 10/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6040 - accuracy: 0.7885 - val_loss: 0.6751 - val_accuracy: 0.7667
# Epoch 11/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5851 - accuracy: 0.7922 - val_loss: 0.6660 - val_accuracy: 0.7742
# Epoch 12/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5672 - accuracy: 0.8013 - val_loss: 0.6893 - val_accuracy: 0.7732
# Epoch 13/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5471 - accuracy: 0.8069 - val_loss: 0.6981 - val_accuracy: 0.7701
# Epoch 14/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5246 - accuracy: 0.8136 - val_loss: 0.6945 - val_accuracy: 0.7747
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping

# %% [markdown]
# #### Оценка качества модели

# %%
_, accuracy_value = model.evaluate(x=test_x[:], y=test_y[:], batch_size=12)
print("Final Accuracy: %5.2f %%" % (accuracy_value * 100))
# Out:
# 834/834 [==============================] - 2s 2ms/step - loss: 0.6660 - accuracy: 0.7742
# Final Accuracy: 77.42 %

# %% [markdown]
# #### Функция для инференса и отображения результата предсказания

# %%
def test_item(sample):
    
    logits = model(sample[None, ...])[0]
    prediction = tf.nn.softmax(logits)
    ans = np.argmax(prediction)
    
    fig = plt.figure(figsize=(12,4))

    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(sample[:,:,:])
    plt.xticks([]), plt.yticks([])

    ax = fig.add_subplot(1, 2, 2)
    bar_list = ax.bar(np.arange(10), prediction, align='center')
    bar_list[ans].set_color('g')
    ax.set_xticks(np.arange(10))
    ax.set_xlim([-1, 10])
    ax.grid(True)

    plt.show()
    
    print('Predicted: {}'.format(ans))

# %% [markdown]
# #### Запуск предсказания для изображения случайного изображения из CIFAR-10

# %%
import random
idx = random.randint(0, test_x.shape[0])
sample = test_x[idx, ...]
test_item(sample)

print('True Answer: {}'.format(test_y[idx]))
# Out:
# Predicted: 7
# True Answer: 7
